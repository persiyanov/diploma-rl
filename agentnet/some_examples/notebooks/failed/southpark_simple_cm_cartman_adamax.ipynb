# %%
# %env THEANO_FLAGS=device=gpu1
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append("..")
# Out:
# env: THEANO_FLAGS=device=gpu1

# %% [markdown]
# # Subj
#
# Tried to use adamax with default parameters. Works worse than adam.

# %%
from utils.southpark import get_conversations
conversations = get_conversations("/srv/hd7/jheuristic/cartman/sp.json")
    
from utils.preprocessor import Preprocessor

preproc = Preprocessor.from_conversations(conversations,verbose=True)
# Out:
# 100%|██████████| 7285/7285 [00:03<00:00, 2159.62it/s]
# 23281 out of 23281 tokens, coverage=1.00000)

# %% [markdown]
# # model

# %%
from models.twoline_model import ConversationModel

import lasagne

model = ConversationModel(preproc,bottleneck_size=512,optimizer=lasagne.updates.adamax)

# %% [markdown]
# # training

# %%
max_len=10
batch_size=100
n_epochs=100

# %%
from utils.generate import get_phrase_pairs,iterate_minibatches

convs_ix = list(preproc.preprocess_conversations(conversations,verbose=True,max_len=max_len))

prev_phrases,reference_answers = get_phrase_pairs(convs_ix,
                                                  speaker_filter = lambda s1,s2: 'cartman' in s2).swapaxes(0,1).astype('int32')
# Out:
# 100%|██████████| 7285/7285 [00:03<00:00, 1888.21it/s]

# %%
epoch_counter = 1
ce = []

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
for _ in range(n_epochs):
    for b_x,b_y in iterate_minibatches([prev_phrases,reference_answers],batch_size,shuffle=True):
        ce.append(model.train_fun(b_x,b_y))
        
        epoch_counter +=1
        
        if epoch_counter %25==0:
            print epoch_counter,'iterations...'
    print "beginning new loop..."
    plt.plot(ce)
    plt.show()
    
    ph =preproc.ix_to_phrase(b_x[0])
    print 'A:', ph
    print 'B:', model.reply(ph)
    print 'B true:',preproc.ix_to_phrase(b_y[0])
# Out:
# 25 iterations...
# 50 iterations...
# 75 iterations...
# beginning new loop...
# A: the world doesn't revolve around me ?
# B: mom get ah do call , , i ! ! i'm i you kyle . . out i some that know awesom your you in should friends heard screwed cool kyle ! their to . a can . is that a people i'm the the in saturday my the are i in , you
# B true: maybe the world doesn't revolve around me .
# 100 iterations...
# 125 iterations...
# 150 iterations...
# 175 iterations...
# beginning new loop...
# A: huh ?
# B: i one . hell ! i supposed i fucking these think pirate , billion the something going life tacos way ! me first to on i : we in
# B true: i mean , germany was united under the swastika
# 200 iterations...
# 225 iterations...
# 250 iterations...
# beginning new loop...
# A: yeah .
# B: oh funny what , can about and , 72 me for go the be will black and that all
# B true: i've gotta tell you something , kyle . the
# 275 iterations...
# 300 iterations...
# 325 iterations...
# 350 iterations...
# beginning new loop...
# A: nobody's blood is going to jump up in the
# B: why this hah it thank this a we your you . recess the maybe
# B true: if it isn't going to work , then what
# 375 iterations...
# 400 iterations...
# 425 iterations...
# 450 iterations...
# beginning new loop...
# A: i didn't " bail , " i got picked
# B: . got can't that oh a inform ? all fame i chef you've
# B true: well we're here now , that's all that matters
# 475 iterations...
# 500 iterations...
# 525 iterations...
# beginning new loop...
# A: there , what do you think ?
# B: yeah ! usda no if we you're . . . i
# B true: what the hell is
# 550 iterations...
# 575 iterations...
# 600 iterations...
# 625 iterations...
# beginning new loop...
# A: okay , let's go !
# B: red howard , kyle my mom . .
# B true: oh , i didn't think you were coming ,
# 650 iterations...
# 675 iterations...
# 700 iterations...
# beginning new loop...
# A: no , you're fat to begin with , chubby
# B: that's . i david to doing even agreement with
# B true: oh yeah ? ! oh yeah ? ! well
# 725 iterations...
# 750 iterations...
# 775 iterations...
# 800 iterations...
# beginning new loop...
# A: attention south park students : will the following students
# B: dude , you guys of you got , coming
# B true: oh jesus , what now ? !
# 825 iterations...
# 850 iterations...
# 875 iterations...
# 900 iterations...
# beginning new loop...
# A: glad i picked you up , kid . it's
# B: sure ! it's just minute . it's a
# B true: yeah well , when a man has been wronged
# 925 iterations...
# 950 iterations...
# 975 iterations...
# beginning new loop...
# A: we don't know . he's everywhere .
# B: do you don't want be name , i'm you're
# B true: look , you morons , slash clearly has a
# 1000 iterations...
# 1025 iterations...
# 1050 iterations...
# 1075 iterations...
# beginning new loop...
# A: eric , will you please ,
# B: tell my see my asshole ! he's sorry ,
# B true: why ?
# 1100 iterations...
# 1125 iterations...
# 1150 iterations...
# beginning new loop...
# A: oh .
# B: kyle , dude ! movin' loudly . she case difficult rache
# B true: what's the matter , kyle ? you chicken ?
# 1175 iterations...
# 1200 iterations...
# 1225 iterations...
# 1250 iterations...
# beginning new loop...
# A: . . . oh right , i , i'm
# B: yeah , heh in it ! i was really
# B true: youuu save it all ?
# 1275 iterations...
# 1300 iterations...
# 1325 iterations...
# 1350 iterations...
# beginning new loop...
# A: hey , fat ass .
# B: what ? don't shoot great , here happened ! later
# B true: hey , dick - whore . i guess you
# 1375 iterations...
# 1400 iterations...
# 1425 iterations...
# beginning new loop...
# A: over a hundred .
# B: no ! listen , dreamers , you pussies i
# B true: look further down the page . does he list
# 1450 iterations...
# 1475 iterations...
# 1500 iterations...
# 1525 iterations...
# beginning new loop...
# A: the boat went really slow and it just went
# B: kevin time ! buying my maybe headset eat
# B true: waaaaaaaaaaaaah !
# 1550 iterations...
# 1575 iterations...
# 1600 iterations...
# beginning new loop...
# A: no , my parents won't let me bring homeless
# B: i was this are ? except 72 one
# B true: well what do you guys expect me to do
# 1625 iterations...
# 1650 iterations...
# 1675 iterations...
# 1700 iterations...
# beginning new loop...
# A: i bet i get more candy than you dude
# B: that a mobody ! oh the bitch !
# B true: are you crazy ? ! i'm the candy master
# 1725 iterations...
# 1750 iterations...
# 1775 iterations...
# 1800 iterations...
# beginning new loop...
# A: no , i don't ! the decision was overturned
# B: fine ? we guys . you doing that
# B true: we had a deal kyle !
# 1825 iterations...
# 1850 iterations...
# 1875 iterations...
# beginning new loop...
# A: what ?
# B: clear friend . he don't hope here ? thieves you stoked "
# B true: what ?
# 1900 iterations...
# 1925 iterations...
# 1950 iterations...
# 1975 iterations...
# beginning new loop...
# A: then why did you go outside to a police
# B: whoa thousand ? you're christmas order in mine
# B true: oh wait , i get it now ! the
# 2000 iterations...
# 2025 iterations...
# 2050 iterations...
# beginning new loop...
# A: then
# B: running free ! look on and but those you how's this let's … it about two
# B true: but . . . we
# 2075 iterations...
# 2100 iterations...
# 2125 iterations...
# 2150 iterations...
# beginning new loop...
# A: yeah .
# B: turd on , mom . you feel now i'm i .
# B true: you know , there's really only two seasons here
# 2175 iterations...
# 2200 iterations...
# 2225 iterations...
# 2250 iterations...
# beginning new loop...
# A: yeah . you're the one who always plugs up
# B: awww , mike , you're just just to
# B true: ey ! i am a cop , and
# 2275 iterations...
# 2300 iterations...
# 2325 iterations...
# beginning new loop...
# A: eric , you have to get in the deep
# B: you're not knows this on , clyde know .
# B true: later's fine .
# 2350 iterations...
# 2375 iterations...
# 2400 iterations...
# 2425 iterations...
# beginning new loop...
# A: yeah !
# B: what ? is just does this is , he
# B true: all right ! you have to be in me
# 2450 iterations...
# 2475 iterations...
# 2500 iterations...
# beginning new loop...
# A: that's not what she said . you're putting extras
# B: noohoho ! built me again ! about your funny
# B true: i know dude . the bathroom is the last
# 2525 iterations...
# 2550 iterations...
# 2575 iterations...
# 2600 iterations...
# beginning new loop...
# A: come on guys . it's not worth it .
# B: brady ! you have to hold ! i won't
# B true: why don't you make me ?
# 2625 iterations...
# 2650 iterations...
# 2675 iterations...
# 2700 iterations...
# beginning new loop...
# A: i'll meet up with you guys in a little
# B: it d'ja fun hewitt ! if you found
# B true: okay , kyle . we're gonna get splashed some
# 2725 iterations...
# 2750 iterations...
# 2775 iterations...
# beginning new loop...
# A: nice tooth fairy costume . you think anybody'd believe
# B: no . about it ! pecan go
# B true: it's better than
# 2800 iterations...
# 2825 iterations...
# 2850 iterations...
# 2875 iterations...
# beginning new loop...
# A: okay . now , in order for us the
# B: heh . did somebody never over finish .
# B true: it's okay , i'm here .
# 2900 iterations...
# 2925 iterations...
# 2950 iterations...
# beginning new loop...
# A: you broke the rules , how you found out
# B: it's being a easy of its game song with
# B true: yeah , you broke the rules !
# 2975 iterations...
# 3000 iterations...
# 3025 iterations...
# 3050 iterations...
# beginning new loop...
# A: i would rather game with craig than spend one
# B: you guys ! call token ! you heart
# B true: you're outnumbered ten to one , and there's no
# 3075 iterations...
# 3100 iterations...
# 3125 iterations...
# 3150 iterations...
# beginning new loop...
# A: oh hey eric . just workin' on some jokes
# B: dear please , except this idea or you talking
# B true: that's cool . you wanna write some together ?
# 3175 iterations...
# 3200 iterations...
# 3225 iterations...
# beginning new loop...
# A: it's true . we were wrong for deceiving you
# B: ooohhhh . look to be ready fags .
# B true: hey , how come
# 3250 iterations...
# 3275 iterations...
# 3300 iterations...
# 3325 iterations...
# beginning new loop...
# A: people don't hate the jews !
# B: this is ridiculous ! no your biiitch whistlin' music i'm
# B true: really ? three hundred million domestic box - office
# 3350 iterations...
# 3375 iterations...
# 3400 iterations...
# beginning new loop...
# A: hey , there
# B: it , dude , what ? ! get a
# B true: i told you , token .
# 3425 iterations...
# 3450 iterations...
# 3475 iterations...
# 3500 iterations...
# beginning new loop...
# A: yee - haw ! all right !
# B: nobody brand worm ! uuugh ! streible chicks is
# B true: now our numbers are truly great . it is
# 3525 iterations...
# 3550 iterations...
# 3575 iterations...
# 3600 iterations...
# beginning new loop...
# A: dude , what are we gonna do ? we
# B: butters . you can let those lawy -
# B true: wiat . i've got it , you guys .
# 3625 iterations...
# 3650 iterations...
# 3675 iterations...
# beginning new loop...
# A: okay , cartman . you ready ?
# B: a course and i saw fluffy . scott
# B true: nnoo .
# 3700 iterations...
# 3725 iterations...
# 3750 iterations...
# 3775 iterations...
# beginning new loop...
# A: that's only a vaccination for girls , stupid !
# B: slash needs like in up ! a colonel !
# B true: then why are they sayin' that gettin' vaccinated at
# 3800 iterations...
# 3825 iterations...
# 3850 iterations...
# beginning new loop...
# A: but . . .
# B: butters , you know that , you look certainly we
# B true: butters ? ! come on , we gotta go
# 3875 iterations...
# 3900 iterations...
# 3925 iterations...
# 3950 iterations...
# beginning new loop...
# A: tom , the convicts were about to be arrested
# B: more , he call whiz to … born ticket
# B true: oh my god , this is it , butters
# 3975 iterations...
# 4000 iterations...
# 4025 iterations...
# 4050 iterations...
# beginning new loop...
# A: well i'm sorry , eric . i , i
# B: oh , my way off of their second -
# B true: what new people ?
# 4075 iterations...
# 4100 iterations...
# 4125 iterations...
# beginning new loop...
# A: shut up , cartman ?
# B: there's a lost - cow taking me . let's
# B true: you shut up ,
# 4150 iterations...
# 4175 iterations...
# 4200 iterations...
# 4225 iterations...
# beginning new loop...
# A: that's true . you did .
# B: i am , gonna tell you polly . i
# B true: oh , look at you go , kyle !
# 4250 iterations...
# 4275 iterations...
# 4300 iterations...
# beginning new loop...
# A: you guys , i feel kinda bad for that
# B: . . okay , eh . . . they
# B true: you feel bad for him ? ! he has
# 4325 iterations...
# 4350 iterations...
# 4375 iterations...
# 4400 iterations...
# beginning new loop...
# A: oh . . . thank you .
# B: and . . . no , peter . .
# B true: dude , i think it's totally working . the
# 4425 iterations...
# 4450 iterations...
# 4475 iterations...
# 4500 iterations...
# beginning new loop...
# A: i just didn't think it would come so soon
# B: ey ! bitch ! you look for sometimes
# B true: yeah . only now do we realize how much
# 4525 iterations...
# 4550 iterations...
# 4575 iterations...
# beginning new loop...
# A: then he's perfect for us .
# B: lunch , what are every gettin' old brave musica
# B true: what should we name him , kenny ? i
# 4600 iterations...
# 4625 iterations...
# 4650 iterations...
# 4675 iterations...
# beginning new loop...
# A: this is exactly what you would do if they
# B: well , i'm sorry at my black .
# B true: i don't think so , kyle ! but you
# 4700 iterations...
# 4725 iterations...
# 4750 iterations...
# beginning new loop...
# A: " ike , i long to feel your arms
# B: hello , if stop this is pretty gay ,
# B true: yes . during classtime , without a hall pass
# 4775 iterations...
# 4800 iterations...
# 4825 iterations...
# 4850 iterations...
# beginning new loop...
# A: they said we have to give them money that
# B: trust it ! they're it messin' thinking .
# B true: how are we supposed to make money on the
# 4875 iterations...
# 4900 iterations...
# 4925 iterations...
# 4950 iterations...
# beginning new loop...
# A: what ? !
# B: craig , that looks like we can go sometimes
# B true: i'll bet you can't , because you guys are
# 4975 iterations...
# 5000 iterations...
# 5025 iterations...
# beginning new loop...
# A: this is a clinic to help you get over
# B: testaburger ! i'm not from their fili from it
# B true: who wants just gravy ? ! it goes on
# 5050 iterations...
# 5075 iterations...
# 5100 iterations...
# 5125 iterations...
# beginning new loop...
# A: damn , dude .
# B: yayy ! the i'm gonna get off that
# B true: yayy !
# 5150 iterations...
# 5175 iterations...
# 5200 iterations...
# beginning new loop...
# A: charging .
# B: it i , i i'm ? you i
# B true: do it !
# 5225 iterations...
# 5250 iterations...
# 5275 iterations...
# 5300 iterations...
# beginning new loop...
# A: come on , cartman ! how much do you
# B: ha ! there's no until adam bracelets this !
# B true: well , this war is about slavery , so
# 5325 iterations...
# 5350 iterations...
# 5375 iterations...
# 5400 iterations...
# beginning new loop...
# A: i'm glad that you could all come . i
# B: well now , we just don't have to who
# B true: just tell us already !
# 5425 iterations...
# 5450 iterations...
# 5475 iterations...
# beginning new loop...
# A: " here's my snout . "
# B: sons on turd please . " bluh probably sue
# B true: here's my snout .
# 5500 iterations...
# 5525 iterations...
# 5550 iterations...
# 5575 iterations...
# beginning new loop...
# A: huh , mere peanuts . chocolate rain has done
# B: your people , what's your mom's one surgery !
# B true: dude , screw you . your internet thing was
# 5600 iterations...
# 5625 iterations...
# 5650 iterations...
# beginning new loop...
# A: spearheaded by you , m'kay , made him feel
# B: we were pretty getting kidding now good , you're
# B true: 'kay , whoa , whoa ! we've been through
# 5675 iterations...
# 5700 iterations...
# 5725 iterations...
# 5750 iterations...
# beginning new loop...
# A: okay , hon .
# B: t . uh , what ? kyle goin'
# B true: t ö ten sie die juden . wir k
# 5775 iterations...
# 5800 iterations...
# 5825 iterations...
# 5850 iterations...
# beginning new loop...
# A: how can you say that ? did you see
# B: well , it going on the conversation , here
# B true: who cares ? ?
# 5875 iterations...
# 5900 iterations...
# 5925 iterations...
# beginning new loop...
# A: i can shoot
# B: if we did it ! ow !
# B true: i can shoot you too !
# 5950 iterations...
